# %% [markdown]
# # CSDA Evaluation Sites overview
#
# Paul Montesano, PhD
# August 2025

# %%
library(ggplot2)
library(sf)
library(rnaturalearth)
library(rnaturalearthdata)
library(tidyverse)
library(ggrepel)
library(RColorBrewer)

# %%
SHEET_NAME <- 'Evaluation Sites'

# URL encode using base R
ENCODED_SHEET_NAME <- URLencode(SHEET_NAME, reserved = TRUE)

# Construct URL
url <- paste0("https://docs.google.com/spreadsheets/d/", SPREADSHEET_ID, 
              "/gviz/tq?tqx=out:csv&sheet=", ENCODED_SHEET_NAME)

# Read and process
tryCatch({
    sites_df <- read.csv(url, stringsAsFactors = FALSE) %>% 
        select(-starts_with("X"))
    sites_df$Site.Name <- trimws(sites_df$Site.Name, which = "right")
    
}, error = function(e) {
    message("An error occurred: ", e$message)
})

colnames(sites_df)
# Out:
#  [1] "Site.Name"                "Location.Name"
#  [3] "Country"                  "Longitude"
#  [5] "Latitude"                 "Domain"
#  [7] "Priority.Level"           "Evaluation.Category"
#  [9] "Site.min.sqkm"            "Max.View.Angle"
# [11] "Min...of.Acqs.Sensor"     "Max.Cloud.."
# [13] "acquisition.sqkm"         "Source"
# [15] "Assessment.type.s."       "Notes"
# [17] "UL..Latitude..Longitude." "LL..Latitude..Longitude."
# [19] "UR..Latitude..Longitude." "LR..Latitude..Longitude."

# %%
#sites_df = read_csv('/projects/my-private-bucket/databank/csda/CSDA SME Evaluation Sites(SME sites).csv')

# %%
# Convert to sf object
sites_sf <- st_as_sf(sites_df %>% 
                     filter(
                         !is.na(`Longitude`),
                         !is.na(`Evaluation.Category`),
                     ), 
                     #coords = c('Longitude (deg)', 'Latitude (deg)'), crs = 4326)
                     coords = c('Longitude', 'Latitude'), crs = 4326)

# %%
head(sites_sf,2)
# Out:
#   Site.Name   Location.Name Country Domain              Priority.Level
# 1 Albuquerque New Mexico    USA     Optical Multi       high
# 2 Baotou      China cal/val China   Optical Multi/Hyper low
#   Evaluation.Category     Site.min.sqkm Max.View.Angle Min...of.Acqs.Sensor
# 1 Geometric               20.00         30             5
# 2 Radiometric & Geometric  0.04          5             2
#   Max.Cloud.. acquisition.sqkm Source
# 1 15          1200
# 2  0           800             RadCalNet
#   Assessment.type.s.                                                  Notes
# 1 Geometric Calibration Quality (priority pointing site)
# 2 Radiometric, Geometric Calibration Quality (LSF/MTF, for res < 6 m)
#   UL..Latitude..Longitude. LL..Latitude..Longitude. UR..Latitude..Longitude.
# 1
# 2
#   LR..Latitude..Longitude. geometry
# 1                          POINT (-106.6138 35.06871)
# 2                          POINT (109.6294 40.85179)

# %%
# Get world data for continents
world <- ne_countries(scale = "medium", returnclass = "sf")

# %%
options(repr.plot.width = 5, repr.plot.height = 3, repr.plot.res = 300)

# Define orthographic projection (centered on 0°, 0°)
ortho_proj <- "+proj=ortho +lon_0=0 +lat_0=30 +ellps=WGS84 +datum=WGS84 +units=m +no_defs"
eckert6_proj <- "+proj=eck6 +lon_0=0 +x_0=0 +y_0=0 +ellps=WGS84 +datum=WGS84 +units=m +no_defs"

proj = eckert6_proj

# Transform data to orthographic projection
#world_ortho <- st_transform(world, crs = ortho_proj)
world_proj = st_cast(world, 'MULTILINESTRING') %>%
  st_cast('LINESTRING', do_split = TRUE) %>%
  st_transform(crs = proj) %>%
  # mutate(npts = npts(geometry, by_feature = TRUE)) %>%
  # filter(npts > 3) %>%
  st_cast('POLYGON')

sites_proj <- st_transform(sites_sf, crs = proj)

# Create a circle to represent the globe edge
# Earth's radius is approximately 6371000 meters
earth_radius <- 6371000
globe_edge <- st_buffer(st_point(c(0, 0)), earth_radius)
globe_edge_sf <- st_sfc(globe_edge, crs = proj)

# Create graticule (grid lines)
graticule <- st_graticule(lat = seq(-90, 90, 30), lon = seq(-180, 180, 30))
graticule_proj <- st_transform(graticule, crs = proj)

# Create the plot
base_map = ggplot() +
  # # First, draw the globe background (white circle)
  # geom_sf(data = globe_edge_sf, fill = "white", color = "black", size = 0.5) +
  # Optional: Add graticule for reference
  geom_sf(data = graticule_proj, color = "lightgray", size = 0.2, alpha = 0.5) +
  # Then add the continents
  geom_sf(data = world_proj, fill = "gray", color = "darkgray", size = 0.1) +
  theme_void() +
  theme(
    panel.background = element_rect(fill = "white", color = NA),
    plot.background = element_rect(fill = "white", color = NA),
      legend.text = element_text(size=6),
      legend.title = element_text(size=7),
      legend.position = "top",
    legend.direction = "horizontal",
      #legend.spacing.y = unit(0.01, "cm") 
  ) +
  #labs(title = "Site Locations - Orthographic Projection") +
  coord_sf(crs = proj)
# Out:
# Warning message in st_cast.sf(., "LINESTRING", do_split = TRUE):
# “repeating attributes for all sub-geometries for which they may not be constant”

# %%
base_map +   # Finally add the site points
  geom_sf(data = sites_proj, aes(color=`Evaluation.Category`), size = 2, shape=1) +
  # geom_sf_label(data = sites_ortho, aes(label = `Site Name`, color=`Evaluation Category`), 
  #              nudge_x = 7e5, nudge_y = 7e5, size = 0.25) +
    scale_color_brewer(palette = 'Dark2', name=paste0('CSDA\nEvaluation\nSites '),
                       guide = guide_legend(
                           ncol=2,
          override.aes = list(
            size = 2,          # Point size
            label = ""         # Remove text from legend
          )
        )
                      )
# Out:
# Coordinate system already present. Adding new coordinate system, which will
# replace the existing one.
# plot without title

# %%
site_strings <- c('Albuquerque', 'Singapore', 'Rio Gallegos', 'Libya-4','Casablanca','Catania', 'Baotou')
pattern <- paste(site_strings, collapse = "|")

sites_proj_subset = sites_proj %>% filter(grepl(pattern, `Site.Name`, ignore.case = TRUE))

# %%
head(sites_proj_subset, 30)
# Out:
#   Site.Name    Location.Name Country   Domain              Priority.Level
# 1 Baotou       China cal/val China     Optical Multi/Hyper low
# 2 Catania      Sicily        Italy     Optical Multi       unknown
# 3 PICS Libya-4 PICS Libya-4  Libya     Optical Multi       unknown
# 4 Singapore    Singapore     Singapore Optical Multi       unknown
#   Evaluation.Category     Site.min.sqkm Max.View.Angle Min...of.Acqs.Sensor
# 1 Radiometric & Geometric  0.04          5              2
# 2 Geometric               20.00         30              3
# 3 Radiometric                NA         NA             NA
# 4 Geometric               20.00         30              5
#   Max.Cloud.. acquisition.sqkm Source
# 1  0           800             RadCalNet
# 2 15            NA             NASA
# 3 NA          1600             USGS
# 4 15          1200             NASA
#   Assessment.type.s.                                                  Notes
# 1 Radiometric, Geometric Calibration Quality (LSF/MTF, for res < 6 m)
# 2 Geometric Calibration Quality (additional pointing site)
# 3 Radiometric Calibration Quality (Temporal)
# 4 Geometric Calibration Quality (priority pointing site)
#   UL..Latitude..Longitude. LL..Latitude..Longitude. UR..Latitude..Longitude.
# 1
# 2
# 3
# 4
#   LR..Latitude..Longitude. geometry
# 1                          POINT (8732188 5057017)
# 2                          POINT (1240057 4655881)
# 3                          POINT (2072573 3573776)
# 4                          POINT (10193402 165197.3)

# %%
base_map +   # Finally add the site points
  geom_sf(data = sites_proj_subset
          , aes(color=`Evaluation.Category`), size = 2, shape=1) +
  geom_sf_label(data = sites_proj_subset, aes(label = `Site.Name`, color=`Evaluation.Category`), 
               nudge_x = 7e5, nudge_y = 7e5, size = 1.75, show.legend = FALSE) +
  geom_sf_text(data = sites_proj_subset, aes(label = `Site.Name`), 
               nudge_x = 7e5, nudge_y = 7e5, size = 1.75, show.legend = FALSE) +
    scale_color_brewer(palette = 'Dark2', name=paste0('CSDA\nEvaluation\nSites '),
                       guide = guide_legend(
                           ncol=2,
          override.aes = list(
            size = 2,          # Point size
            label = ""         # Remove text from legend
          )
        )
                      )
# Out:
# Coordinate system already present. Adding new coordinate system, which will
# replace the existing one.
# plot without title
